# %%
import re
import json

def convert_to_json(text):
    data = {}

    # Extracting user_id
    user_id_match = re.search(r'user id', text)
    data["user_id"] = user_id_match.group(1) if user_id_match else None

    # Extracting statement_id
    statement_id_match = re.search(r'Statement ID', text)
    data["statement_id"] = statement_id_match.group(1) if statement_id_match else None

    # Extracting identity
    identity_match = re.search(r'identity', text)
    data["identity"] = identity_match.group() if identity_match else None

    # Extracting bank
    bank_match = re.search(r'Name of the Bank', text)
    data["bank"] = bank_match.group() if bank_match else None

    # Extracting credit_card_number
    credit_card_number_match = re.search(r'Credit Card Number\r\n(XXXX XXXX XXXX XX\d{2})', text)
    data["credit_card_number"] = credit_card_number_match.group(1) if credit_card_number_match else None

    # Extracting name
    name_match = re.search(r'name', text)
    data["name"] = name_match.group() if name_match else None

    # Extracting address
    address_match = re.search(r'address', text)
    data["address"] = address_match.group() if address_match else None

    # Extracting payment_due_date
    payment_due_date_match = re.search(r'Payment Due Date\n(\d{2} [A-Za-z]{3} \d{4})', text)
    data["payment_due_date"] = payment_due_date_match.group(1) if payment_due_date_match else None

    # Extracting total_dues
    total_dues_match = re.search(r'Total Amount Due \(₹\)\n([0-9,.]+)', text)
    data["total_dues"] = total_dues_match.group(1) if total_dues_match else None

    # Extracting min_amt_due
    min_amt_due_match = re.search(r'Minimum Amount Due \(₹\)\n([0-9,.]+)', text)
    data["min_amt_due"] = min_amt_due_match.group(1) if min_amt_due_match else None

    # Extracting finance_charges
    finance_charges_match = re.search(r'Fee, Taxes & Interest Charges \(₹\)\t([0-9,.]+)', text)
    data["finance_charges"] = finance_charges_match.group(1) if finance_charges_match else None

    # Extracting credit_limit
    credit_limit_match = re.search(r'Credit Limit \(₹ \) \(including cash\)\t([0-9,.]+)', text)
    data["credit_limit"] = credit_limit_match.group(1) if credit_limit_match else None

    # Extracting avl_credit_limit
    avl_credit_limit_match = re.search(r'Available Credit Limit \(₹\)\t([0-9,.]+)', text)
    data["avl_credit_limit"] = avl_credit_limit_match.group(1) if avl_credit_limit_match else None

    # Extracting cash_limit
    cash_limit_match = re.search(r'Cash Limit \(₹ \(as part of credit limit\)\t([0-9,.]+)', text)
    data["cash_limit"] = cash_limit_match.group(1) if cash_limit_match else None

    # Extracting avl_cash_limit
    avl_cash_limit_match = re.search(r'Available Cash Limit \(₹\)\t([0-9,.]+)', text)
    data["avl_cash_limit"] = avl_cash_limit_match.group(1) if avl_cash_limit_match else None

    # Extracting opening_balance
    opening_balance_match = re.search(r'Previous Balance \(₹\)\t([0-9,.]+)', text)
    data["opening_balance"] = opening_balance_match.group(1) if opening_balance_match else None

    # Extracting payment_or_credits
    payment_or_credits_match = re.search(r'Payments, Reversals & other Credits \(₹\)\t([0-9,.]+)', text)
    data["payment_or_credits"] = payment_or_credits_match.group(1) if payment_or_credits_match else None

    # Extracting purchase_or_debits
    purchase_or_debits_match = re.search(r'Purchases & Other Debits \(₹\)\t([0-9,.]+)', text)
    data["purchase_or_debits"] = purchase_or_debits_match.group(1) if purchase_or_debits_match else None

    # Extracting statement_date
    statement_date_match = re.search(r'Statement Date\n(\d{2} [A-Za-z]{3} \d{4})', text)
    data["statement_date"] = statement_date_match.group(1) if statement_date_match else None

    # Extracting points_earned
    points_earned_match = re.search(r'Points earned', text)
    data["points_earned"] = points_earned_match.group() if points_earned_match else None

    # Extracting total_points
    total_points_match = re.search(r'Total Reward points', text)
    data["total_points"] = total_points_match.group() if total_points_match else None

    # Extracting transactions
    transactions = re.findall(r'(\d{2} [A-Za-z]{3} \d{2})\t(.*?)\t(-?[0-9,.]+)\s+(C|D)\n', text)
    data["transactions"] = []
    for transaction in transactions:
        transaction_data = {
            "date": transaction[0],
            "transaction_details": transaction[1],
            "amount": transaction[2],
            "transaction_type": "Credit" if transaction[3] == "C" else "Debit",
            "transaction_ref_number": None
        }
        data["transactions"].append(transaction_data)

    return json.dumps(data, indent=4)

input_text = """BPCL SBI Card OCTANE\r\nMonthly Statement\r\nSBI card\r\nGSTIN of SBI Card 06AAECS5981K1ZV\r\nStmt/Debit Note/Credit Note/Tax Invoice\r\n(DUPLICATE FOR SUPPLIER)\r\nSUNIL KUMAR YADAV\r\nCredit Card Number\r\nTHAT Pedia HISHI\r\nXXXX XXXX XXXX XX24\r\n*Total Amount Due (₹)\r\nCREDIT\r\n33,051.00\r\nincl. EMI\r\n0000\r\n\r\n\r\nPLACE OF SUPPLY\tUP/9/UTTAR PRADESH\nSTMT No. :\tB21073266361\n\r\n\r\nMinimum Amount Due (₹)\r\n5,717.00\r\nPay Now\r\nThe Expiry Date indicates the\r\nvalidity of your Credit Card\r\n\r\n\r\nCredit Limit (₹ ) (including cash)\tCash Limit (₹ (as part of credit limit)\tStatement Date\n2,00,000.00\t60,000.00\t22 Jul 2021\n\r\n\r\nIS T HAIRT\r\nPEGIN AT the\r\nNEVER SHARE it with anyone!\r\nPT HA HISH To\r\n\r\n\r\nAvailable Credit Limit (₹)\tAvailable Cash Limit (₹)\tPayment Due Date\n1,58,903.54\t60,000.00\t11 Aug 2021\n\r\n\r\nACCOUNT SUMMARY\r\n\r\n\r\n\t\t\t\t\n\t\t\tAdditions\t\nPrevious Balance (₹)\tPayments, Reversals & other Credits (₹)\tPurchases & Other Debits (₹)\tFee, Taxes & Interest Charges (₹)\tTotal Outstanding (₹)\n13,396.71\t13,778.47\t39,150.60\t2,327.62\t41,096.00\n\r\n\r\n©SBICARD\r\nSHOP & SMILE SUMMARY\r\nVISA\r\nVIJAY KUMAR\r\n\r\n\r\nPrevious Balance\tEarned\tRedeemed/Expired /Forfeited\tClosing Balance\tPoints Expiry Details\n2450\t2706\t119\t5037\tNONE\n\r\n\r\nENJOY REWARDS\r\nAT EVERY MILE\r\nAvail exclusive privileges with BPCL SBI Card OCTANE.\r\n\r\n\r\nDate\tTransaction Details for Statement dated 22 Jul 2021\tAmount (₹)\n09 Jul 21\tPETROL TRXN FEE RVRSL EXCLUDING TAX\t39.00 C\n15 Jul 21\tFEE LATE PAYMENT (EXCL TAX 171.00)\t950.00 D\n15 Jul 21\tPETROL TRXN FEE RVRSL EXCLUDING TAX\t38.99 C\n18 Jul 21\tPAYMENT RECEIVED (000000000VSB10122352237\t13,397.00 C\n20 Jul 21\tPETROL TRXN FEE RVRSL EXCLUDING TAX\t22.01 C\n22 Jul 21\tFP EMI '03(EXCL TAX 25.37)\t4,094.00 M\n22 Jul 21\tINTEREST ON EMI\t140.95 D\n22 Jul 21\tFIN CHARGE ON RETAIL (EXCL TAX 158.69)\t881.61 D\n\tIGST DB @ 18.00%\t355.06 D\n\tTRANSACTIONS FOR SUNIL KUMAR YADAV\t\n25 Jun 21\tFLIPKART PAYMENTS GURGAON IN\t1,099.00 D\n25 Jun 21\tFLIPKART PAYMENTS GURGAON IN\t399.00 D\n27 Jun 21\tNAYAN FILLING STATION LUCKNOW IN\t3,088.88 D\n02 Jul 21\tAMAZON PAY INDIA PRIVA BANGALORE IN\t234.82 D\n02 Jul 21\tAMAZON PAY INDIA PRIVA BANGALORE IN\t44.58 D\n02 Jul 21\tAMAZON PAY INDIA PRIVA BANGALORE IN\t306.36 D\n03 Jul 21\tIRCTC WWW.IRCTC.CO. IN\t281.47 D\n03 Jul 21\tFLIPKART PAYMENTS GURGAON IN (Pay in EMIs)\t4,799.00 D\n06 Jul 21\tIRCTC WWW.IRCTC.CO. IN\t278.19 C\n06 Jul 21\tSUDHA FILLING STATION LUCKNOW IN\t3,743.66 D\n08 Jul 21\tPAYTM WWW.PAYTM.COM IN\t2,224.66 D\n08 Jul 21\tIRCTC WWW.IRCTC.CO.IN\t3.28 C\n09 Jul 21\tGOKUL FILLING STATION UNNAO IN\t3,947.39 D\n15 Jul 21\t#FLIPKART PAYMENTS BANGALORE IN (Pay in EMIs)\t11,999.00 D\n15 Jul 21\tHIGHWAY TRUCK SERVICE UNNAO IN\t3,945.36 D\n17 Jul 21\tTRANSFER TO MERCHANT EMI\t11,999.00\n20 Jul 21\tAMAR HIGHWAY SERVICE S UNNAO IN\t3,037.42 D\n\t\t\n\r\n\r\n7.25% Value back on spends at BPCL\r\nFuel stations\r\n4\r\n6.25% Value back on Bharatgas payments\r\nthrough Website and Mobile app\r\nM\r\n10X Reward Points on Departmental\r\nstores, Grocery, Movies & Dining spends\r\n4 Complimentary Domestic Airport\r\nLounge Access in a year\r\n*T&C Apply\r\nSTAY HEALTHY.\r\nSTAY SAFE.\r\nExclusive savings at 1mg\r\nUp to 20% Discount on medicines\r\n10% Off on E-consultation\r\nPromo Code: SBI1MG2021\r\nValid till 31 Dec 2021\r\nTransactions highlighted in grey color, if any, do not form part of Purchases & Other Debits; #Transactions lly/partially converted to Flexipay/Encash/Merchant EMI.\r\nC=Credit; D=Debit; EN=Encash; FP=Flexipay; EMD=Easy Money Draft; BT=Balance Transfer; M=Monthly Installments; TAD=Total Amount Due; Temporary Credit.\r\nImportant Messages\r\n>W.e.f. 01 Sep 2021, the rate of finance charges will be revised to 2.75% p.m. from 2.5% p.m. on all secured SBI Credit Card.\r\n>\r\nW.e.f. 01 Sep 2021, the fee levied on cash payment at bank branches towards the Total Amount Due against your SBI Credit Card will be revised to Rs. 250 from Rs. 199. Please note, this charge is excluding\r\napplicable taxes.\r\n>\r\nW.e.f. 01 Sep 2021, the fee of Rs. 200 levied on any new request related to increase of credit limit or for changing the network on your SBI Credit Card will not be applicable.\r\n> Please note, processing fees to be levied on booking of merchant EMI for all credit card transactions of value greater than Rs. 10,000 has been deferred until further notice.\r\n> Please note, conversion of negative Reward Points balance to statement debit of equivalent amount, in case of negative Reward Points balance for 2 consecutive statement cycles, has been deferred until further notice. T&C.\r\n*Total Amount Due (TAD) needs to be paid by payment due date to avoid levy of finance charges on new transactions done after the statement date. The difference. if any, between the Total Amount Due and the Total\r\nOutstanding is the balance on the Flexipay/Encash/Installmentsas applicable\r\n**\r\nTo\r\nkeep your credit card in good standing, you have the option of paying atleast the minimum amount due on or before the due date. The Minimum Amount Due includes the EMI on Flexipay/Encash/Installment\r\namounts & 100% of all applicable taxes. Content of this statement will be considered correct if no error is reported within 20 days.
"""
print(convert_to_json(input_text))
# Out:
# {
#     "user_id": null,
#     "statement_id": null,
#     "identity": null,
#     "bank": null,
#     "credit_card_number": null,
#     "name": null,
#     "address": null,
#     "payment_due_date": null,
#     "total_dues": null,
#     "min_amt_due": null,
#     "finance_charges": null,
#     "credit_limit": null,
#     "avl_credit_limit": null,
#     "cash_limit": null,
#     "avl_cash_limit": null,
#     "opening_balance": null,
#     "payment_or_credits": null,
#     "purchase_or_debits": null,
#     "statement_date": null,
#     "points_earned": null,
#     "total_points": null,
#     "transactions": [
#         {
#             "date": "09 Jul 21",
#             "transaction_details": "PETROL TRXN FEE RVRSL EXCLUDING TAX",
#             "amount": "39.00",
#             "transaction_type": "Credit",
#             "transaction_ref_number": null
#         },
#         {
#             "date": "15 Jul 21",
#             "transaction_details": "FEE LATE PAYMENT (EXCL TAX 171.00)",
#             "amount": "950.00",
#             "transaction_type": "Debit",
#             "transaction_ref_number": null
#         },
#         {
#             "date": "15 Jul 21",
#             "transaction_details": "PETROL TRXN FEE RVRSL EXCLUDING TAX",
#             "amount": "38.99",
#             "transaction_type": "Credit",
#             "transaction_ref_number": null
#         },
#         {
#             "date": "18 Jul 21",
#             "transaction_details": "PAYMENT RECEIVED (000000000VSB10122352237",
#             "amount": "13,397.00",
#             "transaction_type": "Credit",
#             "transaction_ref_number": null
#         },
#         {
#             "date": "20 Jul 21",
#             "transaction_details": "PETROL TRXN FEE RVRSL EXCLUDING TAX",
#             "amount": "22.01",
#             "transaction_type": "Credit",
#             "transaction_ref_number": null
#         },
#         {
#             "date": "22 Jul 21",
#             "transaction_details": "INTEREST ON EMI",
#             "amount": "140.95",
#             "transaction_type": "Debit",
#             "transaction_ref_number": null
#         },
#         {
#             "date": "22 Jul 21",
#             "transaction_details": "FIN CHARGE ON RETAIL (EXCL TAX 158.69)",
#             "amount": "881.61",
#             "transaction_type": "Debit",
#             "transaction_ref_number": null
#         },
#         {
#             "date": "25 Jun 21",
#             "transaction_details": "FLIPKART PAYMENTS GURGAON IN",
#             "amount": "1,099.00",
#             "transaction_type": "Debit",
#             "transaction_ref_number": null
#         },
#         {
#             "date": "25 Jun 21",
#             "transaction_details": "FLIPKART PAYMENTS GURGAON IN",
#             "amount": "399.00",
#             "transaction_type": "Debit",
#             "transaction_ref_number": null
#         },
#         {
#             "date": "27 Jun 21",
#             "transaction_details": "NAYAN FILLING STATION LUCKNOW IN",
#             "amount": "3,088.88",
#             "transaction_type": "Debit",
#             "transaction_ref_number": null
#         },
#         {
#             "date": "02 Jul 21",
#             "transaction_details": "AMAZON PAY INDIA PRIVA BANGALORE IN",
#             "amount": "234.82",
#             "transaction_type": "Debit",
#             "transaction_ref_number": null
#         },
#         {
#             "date": "02 Jul 21",
#             "transaction_details": "AMAZON PAY INDIA PRIVA BANGALORE IN",
#             "amount": "44.58",
#             "transaction_type": "Debit",
#             "transaction_ref_number": null
#         },
#         {
#             "date": "02 Jul 21",
#             "transaction_details": "AMAZON PAY INDIA PRIVA BANGALORE IN",
#             "amount": "306.36",
#             "transaction_type": "Debit",
#             "transaction_ref_number": null
#         },
#         {
#             "date": "03 Jul 21",
#             "transaction_details": "IRCTC WWW.IRCTC.CO. IN",
#             "amount": "281.47",
#             "transaction_type": "Debit",
#             "transaction_ref_number": null
#         },
#         {
#             "date": "03 Jul 21",
#             "transaction_details": "FLIPKART PAYMENTS GURGAON IN (Pay in EMIs)",
#             "amount": "4,799.00",
#             "transaction_type": "Debit",
#             "transaction_ref_number": null
#         },
#         {
#             "date": "06 Jul 21",
#             "transaction_details": "IRCTC WWW.IRCTC.CO. IN",
#             "amount": "278.19",
#             "transaction_type": "Credit",
#             "transaction_ref_number": null
#         },
#         {
#             "date": "06 Jul 21",
#             "transaction_details": "SUDHA FILLING STATION LUCKNOW IN",
#             "amount": "3,743.66",
#             "transaction_type": "Debit",
#             "transaction_ref_number": null
#         },
#         {
#             "date": "08 Jul 21",
#             "transaction_details": "PAYTM WWW.PAYTM.COM IN",
#             "amount": "2,224.66",
#             "transaction_type": "Debit",
#             "transaction_ref_number": null
#         },
#         {
#             "date": "08 Jul 21",
#             "transaction_details": "IRCTC WWW.IRCTC.CO.IN",
#             "amount": "3.28",
#             "transaction_type": "Credit",
#             "transaction_ref_number": null
#         },
#         {
#             "date": "09 Jul 21",
#             "transaction_details": "GOKUL FILLING STATION UNNAO IN",
#             "amount": "3,947.39",
#             "transaction_type": "Debit",
#             "transaction_ref_number": null
#         },
#         {
#             "date": "15 Jul 21",
#             "transaction_details": "#FLIPKART PAYMENTS BANGALORE IN (Pay in EMIs)",
#             "amount": "11,999.00",
#             "transaction_type": "Debit",
#             "transaction_ref_number": null
#         },
#         {
#             "date": "15 Jul 21",
#             "transaction_details": "HIGHWAY TRUCK SERVICE UNNAO IN",
#             "amount": "3,945.36",
#             "transaction_type": "Debit",
#             "transaction_ref_number": null
#         },
#         {
#             "date": "20 Jul 21",
#             "transaction_details": "AMAR HIGHWAY SERVICE S UNNAO IN",
#             "amount": "3,037.42",
#             "transaction_type": "Debit",
#             "transaction_ref_number": null
#         }
#     ]
# }
