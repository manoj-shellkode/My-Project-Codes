# %%
from langchain_community.document_loaders import AmazonTextractPDFLoader
from langchain_community.document_loaders import PDFPlumberLoader
from langchain.prompts import PromptTemplate
from langchain.llms.bedrock import Bedrock
from langchain.chains import LLMChain
from langchain_core.prompts import ChatPromptTemplate
from langchain_community.chat_models import BedrockChat
import boto3
import botocore

config = botocore.config.Config(
    read_timeout=1800,
    connect_timeout=1800,
    retries={"max_attempts": 10}
)

bedrock_client = boto3.client(
    service_name="bedrock-runtime",
    region_name="us-east-1",
    config=config,
)


model_id = "anthropic.claude-3-sonnet-20240229-v1:0"

model_kwargs =  { 
    "max_tokens": 10000,
    "temperature": 0.0,
    "top_k": 250,
    "top_p": 1,
    "stop_sequences": ["\n\nHuman"],
}

model = BedrockChat(
    client=bedrock_client,
    model_id=model_id,
    model_kwargs=model_kwargs,
)




textract_client = boto3.client("textract", region_name="us-west-2")
textract_features=["LAYOUT"]
file_path = input("Enter S3 file URI : ")
loader = AmazonTextractPDFLoader(file_path,textract_features,client=textract_client)
docs = loader.load()
print("Document Extraction Done")
# Out:
# Document Extraction Done

# %%
all_page_content = ""

for doc in docs:
    all_page_content += doc.page_content

# %%
template = """
    Must convert datas into JSON format
    Example format:
        I need exactly like this below format(Expected format)
        
            "Customs_Station": "",
                "CHA_Details": 
                    "CHA_Code": "", 
                    "CHA_Name": "",
                "BE_Details": 
                    "BE_Number": "", 
                    "BE_Date": "", 
                    "BE_Type": "",( print only the last letter for example if 'N/H' print as 'H')
                "Importer_Details": 
                    "Importer_ID": "", 
                    "PAN": "",
                    "AD_Code": "",
                    "Name": "",
                    "Address": "",
                    "Payment_Method": "",
                "IGM_Details": 
                    "IGM_No": "", 
                    "IGM_Date": "", 
                    "Port_of_Loading": "", 
                    "Country_of_Origin": "", 
                    "Country_of_Consignment": "", 
                    "MBL_Details": 
                        "MBL_No": "", 
                        "MBL_Date": ""(present after 'BL No')

                    "HBL_Details": 
                        "HBL_No": "", 
                        "HBL_Date": ""
                        
                    "Pkgs_Details": 
                        "No_of_Packages": "", (print only the number of packages)
                        "Package_Type": "" (print only the package type, identify the package type in the 'No_of_Packages')

                    "Gross_weight": 
                        "Gross_Wt": "", 
                        "Units": ""

                    "Marks&Nos": ""(only need to be printed in this line ,above to the Invoice_Details, take data from 'Marks&Nos')
                    
                "Invoice_Details": 
                    "Invoice_No": "", 
                    "Invoice_Date": "", 
                    "Supplier_Name": "", (identify and print the supplier name)
                    "Supplier_Address": "", (identify and print the supplier address)
                    "POL_Customs_House": "", (take data only from 'Cust. House')
                    "Incoterms": "", (take datas from 'TOI')
                    "Invoice_Amount": 
                        "Value": "", 
                        "Currency": "", 
                    "Freight_Amount": 
                        "Value": "", 
                        "Currency": "", 
                    "Insurance_Amount": 
                        "Value": "", 
                        "Currency": "",
                        "Insurance_Percentege": ""
                    "Misc_Charges": 
                        "Value": "", 
                        "Currency": ""

                "USD to INR Exchange Value": "",(mention only the INR value)
                "Item_Details": 
                    "Item_No":, (must mention the item number like 1,2..., take from item details)
                    "RITC": "", (take datas only from 'RITC' contains only number)
                    "Description": "", (take datas only from 'Description' , print fully)
                    "Quantity": "", 
                    "Unit_Price": "", 
                    "CTH": "", 
                    "Customs_Duty_Rate": "", 
                    "BCD_amount": "", 
                    "Unit": "", (take datas from 'Unit' it consists like KGS)
                    "Assessable_Value": "", 
                    "CETH": "", (take datas from 'CETH' for example 'NOEXCISE')
                    "Excise Duty Rate": "",
                    "Countervailing Duty Amount": "", 
                    "Educational Cess on CVDs": 
                        "% Rate": "",
                        "Amount": "",
                    "Sec & Higher Edu. Cess on CVD": 
                        "% Rate": "", 
                        "Amount": "",
                    "Customs Educational Cess": 
                        "% Rate": "", 
                        "Amount": "",
                    "Customs Sec & Higher Edu. Cess": 
                        "% Rate": "", 
                        "Amount": "",
                    "Social Welfare Surcharge": 
                        "% Rate": "", 
                        "Amount": "",
                    "IGST": 
                        "% Rate": "", 
                        "Amount": "",
                    "GST Cess": 
                        "% Rate": "", 
                        "Amount": ""

                "Duties": 
                    "TOTAL ASSESSABLE VALUE": "",(take value from 'Ass Val' in 'Item Details')
                    "Inv. Gross Total": "", 
                    "BE Gross Total": "", 
                    "Total Basic Customs Duty": "", 
                    "NCD Duty": "", 
                    "ANTID": "", 
                    "SAFEGUARD DUTY": "", 
                    "CVD": "", 
                    "Sch 2 Spl Excise Duty": "", 
                    "Cess": "", 
                    "GSIA": "", 
                    "TTA": "", 
                    "Edu. Cess CVD": "", 
                    "Customs Edu. Cess": "", 
                    "Health CVD": "", 
                    "Addl Duty - (Imports)": "", 
                    "SHE. Cess CVD": "", 
                    "SH Cust Edu. Cess": "", 
                    "Total_Duty_Payable": ""

                "Container_Details": 
                    "S.No": "",
                    "Seal_No": "", (contains only numbers like for example '2371888')
                    "FCL/LCL": "", (contains only letters)
                    "Container_No": ""

                "Bond_Details":
                    "BondCD": "",
                    "Bond_Number": "",(If you identify the 'Bond_Number' and 'Bond_Amount' are same then strictly leave 'Bond_Number' field as empty)
                    "Bond_Amount": "",(Take from BondAmt)
                    "BGRate": "",
                    "BGAmt": "",
                    "Bond_Debited": "",
                    "BGDebited": ""

                "GSTIN_Details": 
                    "Document_No": "", 
                    "Document_Type": "", 
                    "State_Code": "", 
                    "State_Name": "", 
                    "IGST_Assessable_Value": "", 
                    "IGST_Amount": "", 
                    "GST_Cess_Amount": ""

                "Licence_Details": 
                    "Invoice_No": "", (print data from 'Inv' from 'Licence Details' for example, 1,2... etc)
                    "Item_No": "", 
                    "Licence_No": "", 
                    "Licence_Date": "",(take from Licence Dt)
                    "Reg_No": "", 
                    "Reg_Date": "", (take from Reg.No Dt)
                    "Debit_Value": "", 
                    "Debit_Duty": "", 
                    "Debit_Date": "", 
                    "Debit_Quantity": ""


    Instructions:
        - Do not skip any datas while converting into JSON
        - Understand and create a JSON accurately
        - Strictly provide the results in above format only ,ensure that not to change the Expected format
        - Strictly Avoid mismatching of the datas
        - Mention all the dates accurately
        - Provide results with the exact above format only

    
{datas}
"""

# %%
qa_prompt = PromptTemplate(template=template, input_variables=["datas"])
llm_chain = LLMChain(prompt=qa_prompt, llm=model, verbose= False)
result = llm_chain.run(datas= all_page_content)
print(result)
# Out:
# Here is the data converted into the requested JSON format:
#
# {
#     "Customs_Station": "INMAA1",
#     "CHA_Details": {
#         "CHA_Code": "AABCO5562DCH001",
#         "CHA_Name": "OLS CLEARING AND FORWARDING PR"
#     },
#     "BE_Details": {
#         "BE_Number": "2593805",
#         "BE_Date": "15/03/2024",
#         "BE_Type": "H"
#     },
#     "Importer_Details": {
#         "Importer_ID": "3103003757",
#         "PAN": "AAACK8689AFT001",
#         "AD_Code": "6690003",
#         "Name": "DELFINGEN INDIA PRIVATE LIMITED",
#         "Address": "BUILDING-500C, BLOCK B, INDOSPACE INDUSTRIAL AND LOGISTICS PARK, PANRUTI VILLAGE ORAGADAM SRIPERUMPU 631604",
#         "Payment_Method": "Transaction"
#     },
#     "IGM_Details": {
#         "IGM_No": "2371537",
#         "IGM_Date": "15/03/2024",
#         "Port_of_Loading": "Shanghai",
#         "Country_of_Origin": "CHINA",
#         "Country_of_Consignment": "",
#         "MBL_Details": {
#             "MBL_No": "JJCSHCNY400430",
#             "MBL_Date": "05/03/2024"
#         },
#         "HBL_Details": {
#             "HBL_No": "GXPEW24027184",
#             "HBL_Date": "05/03/2024"
#         },
#         "Pkgs_Details": {
#             "No_of_Packages": "5",
#             "Package_Type": "PLT"
#         },
#         "Gross_weight": {
#             "Gross_Wt": "570.000",
#             "Units": "KGS"
#         }
#     },
#     "Marks&Nos": "AS PER BL",
#     "Invoice_Details": {
#         "Invoice_No": "20230123",
#         "Invoice_Date": "19/02/2024",
#         "Supplier_Name": "NINGGUO BST THERMAL PORDUCTS CO., LT",
#         "Supplier_Address": "NO 10TH, CHUANGXIN NORTH ROAD, NINGGUO CITY, ANHUI PROVINCE",
#         "POL_Customs_House": "CHINA",
#         "Incoterms": "FOB",
#         "Invoice_Amount": {
#             "Value": "3091.20",
#             "Currency": "USD"
#         },
#         "Freight_Amount": {
#             "Value": "12.60",
#             "Currency": "USD"
#         },
#         "Insurance_Amount": {
#             "Value": "0.00",
#             "Currency": "",
#             "Insurance_Percentege": "0.190000%"
#         },
#         "Misc_Charges": {
#             "Value": "311.00",
#             "Currency": "USD"
#         }
#     },
#     "USD to INR Exchange Value": "83.7500",
#     "Item_Details": [
#         {
#             "Item_No": 1,
#             "RITC": "70199000",
#             "Description": "SLEEVE NU-KOOL C-P ALNO 34X0130 ITEM : 1005888",
#             "Quantity": "12000.00",
#             "Unit_Price": "0.119600",
#             "CTH": "70199000",
#             "Customs_Duty_Rate": "10.00 %",
#             "BCD_amount": "13303.20",
#             "Unit": "PCS",
#             "Assessable_Value": "133032.19",
#             "CETH": "NOEXCISE",
#             "Excise Duty Rate": "0.00%",
#             "Countervailing Duty Amount": "0.00",
#             "Educational Cess on CVDs": {
#                 "% Rate": "0.00 %",
#                 "Amount": "0.00"
#             },
#             "Sec & Higher Edu. Cess on CVD": {
#                 "% Rate": "0.00 %",
#                 "Amount": "0.00"
#             },
#             "Customs Educational Cess": {
#                 "% Rate": "0.00 %",
#                 "Amount": "0.00"
#             },
#             "Customs Sec & Higher Edu. Cess": {
#                 "% Rate": "0.00 %",
#                 "Amount": "0.00"
#             },
#             "Social Welfare Surcharge": {
#                 "% Rate": "10.00 %",
#                 "Amount": "1330.30"
#             },
#             "IGST": {
#                 "% Rate": "18.00 %",
#                 "Amount": "26579.80"
#             },
#             "GST Cess": {
#                 "% Rate": "0.00 %",
#                 "Amount": "0.00"
#             }
#         },
#         {
#             "Item_No": 2,
#             "RITC": "70199000",
#             "Description": "SLEEVE NU-KOOL C-P ALNO 34X0150 ITEM : 1005887",
#             "Quantity": "12000.00",
#             "Unit_Price": "0.138000",
#             "CTH": "70199000",
#             "Customs_Duty_Rate": "10.00 %",
#             "BCD_amount": "15349.90",
#             "Unit": "PCS",
#             "Assessable_Value": "153498.69",
#             "CETH": "NOEXCISE",
#             "Excise Duty Rate": "0.00%",
#             "Countervailing Duty Amount": "0.00",
#             "Educational Cess on CVDs": {
#                 "% Rate": "0.00 %",
#                 "Amount": "0.00"
#             },
#             "Sec & Higher Edu. Cess on CVD": {
#                 "% Rate": "0.00 %",
#                 "Amount": "0.00"
#             },
#             "Customs Educational Cess": {
#                 "% Rate": "0.00 %",
#                 "Amount": "0.00"
#             },
#             "Customs Sec & Higher Edu. Cess": {
#                 "% Rate": "0.00 %",
#                 "Amount": "0.00"
#             },
#             "Social Welfare Surcharge": {
#                 "% Rate": "10.00 %",
#                 "Amount": "1535.00"
#             },
#             "IGST": {
#                 "% Rate": "18.00 %",
#                 "Amount": "30669.00"
#             },
#             "GST Cess": {
#                 "% Rate": "0.00 %",
#                 "Amount": "0.00"
#             }
#         }
#     ],
#     "Duties": {
#         "TOTAL ASSESSABLE VALUE": "286530.88",
#         "Inv. Gross Total": "88767.20",
#         "BE Gross Total": "88767.20",
#         "Total Basic Customs Duty": "28653.10",
#         "NCD Duty": "0.00",
#         "ANTID": "0.00",
#         "SAFEGUARD DUTY": "0.00",
#         "CVD": "0.00",
#         "Sch 2 Spl Excise Duty": "0.00",
#         "Cess": "0.00",
#         "GSIA": "0.00",
#         "TTA": "0.00",
#         "Edu. Cess CVD": "0.00",
#         "Customs Edu. Cess": "0.00",
#         "Health CVD": "0.00",
#         "Addl Duty - (Imports)": "0.00",
#         "SHE. Cess CVD": "0.00",
#         "SH Cust Edu. Cess": "0.00",
#         "Total_Duty_Payable": "88767"
#     },
#     "Container_Details": {
#         "S.No": "1",
#         "Seal_No": "2371537",
#         "FCL/LCL": "L",
#         "Container_No": "BHCU5025793"
#     },
#     "Bond_Details": {
#         "BondCD": "PD",
#         "Bond_Number": "",
#         "Bond_Amount": "286531",
#         "BGRate": "0",
#         "BGAmt": "0",
#         "Bond_Debited": "0",
#         "BGDebited": "0"
#     },
#     "GSTIN_Details": {
#         "Document_No": "33AAACK8689A1ZK",
#         "Document_Type": "G",
#         "State_Code": "33",
#         "State_Name": "Tamil Nadu",
#         "IGST_Assessable_Value": "318049",
#         "IGST_Amount": "57249",
#         "GST_Cess_Amount": "0"
#     },
#     "Licence_Details": []
# }
