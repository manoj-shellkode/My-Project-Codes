# %%
from langchain_community.document_loaders import AmazonTextractPDFLoader
from langchain_community.document_loaders import PDFPlumberLoader
from langchain.prompts import PromptTemplate
from langchain.llms.bedrock import Bedrock
from langchain.chains import LLMChain
import boto3
import botocore

config = botocore.config.Config(
    read_timeout=900,
    connect_timeout=900,
    retries={"max_attempts": 3}
)

bedrock_client = boto3.client(
    service_name="bedrock-runtime",
    region_name="us-east-1",
    config=config,
)

textract_client = boto3.client("textract", region_name="us-west-2")
textract_features=["LAYOUT"]
file_path = r"s3://my-s3-doc-loader/2667551.pdf"
loader = AmazonTextractPDFLoader(file_path,textract_features,client=textract_client)
docs = loader.load()

# %%
docs
# Out:
# [Document(page_content='Indian Customs EDI System - Imports V1.5R001\r\nV1.5R001\r\n# BILL OF ENTRY FOR HOME CONSUMPTION\r\n[Custom Stn: INMAA1 CHA : AGGPP7274BCH002 [SUPREME C & F SERVICES ] BE No/Dt./cc/Typ: 2667551/20/03/2024/N/H Importer Details :0798000066 PAN : AAACL2937JFT001 AD Code : 0510010 LIFE STYLE INTERNATIONAL PRIVATE LIMITED 14 : CHENNAI IMPORT WAREHOUSE NO.31/1, POOCHIATHIPET VILLAGE OFF REDHILLS, THIRUVALLUVAR RD REDHILLS CHENNAI 600052 Payment Method : Transaction\r\nIGM No : 2371888/19/03/2024 Cntry of Orgn : CHINA BL No : SZXCB24007583 Date : 08/03/2024 No. of Pkgs. : 628 CTN Marks:AS PER BL & Nos\r\nPort of Loading : Shekou Cntry of Consgn.: H/BL No : RSJ2402518 Date : 08/03/2024 Gross Wt. : 4807.900 KGS\r\nInv No & Dt. : IV2403-0231 07/03/2024 BERGNER HK LIMITED Inv Val : 31087.68 USD TOI: FOB 48/F LANGHAM PLACE OFFICE TOWER 8 Freight : 61975.00 INR ARGYLE ST MONG KOK Insurance : 0.001200% 0.00 HONG KONG SVB Load (Ass) : Cust. House: HK SVB Load (Dty) : HSS Load Rate: 0.00% Amount: 0.00 Misc. Charges: 0.00 0.00 Discount Rate: 0.00 Discount Amount: 0.00 EDD : 0.00 XBE Duty FG Int.: 0.00 Third Party:\r\nBuyerSeller Reltd : No Item Details Exchange rate: 1.00 USD = 83.7500 INR\r\nSlno RITC\tDescription\tRSP\tLoad PROV\r\nQty\tUnit Price\tCTH\tC.Notn C.NSNO\tCus Dty Rt\tBCD amt (Rs)\r\nUnit\tAss Val\tCETH\tE.Notn E.NSNO\tExc Dty Rt\tCVD amt (Rs)\r\n1\t82130000 SS23 S3 KITCHEN SCISSORS TOTAL 1536 SETS USD 1.43\r\nFOB PER SET MADE OF STAINLESS STEEL 37.5X33.5X37.5CM HC 2589\r\n294.40\t7.460870\t82130000\t10.00 %\t18833.60\r\nCus AIDC\t011/2021 17\t0.00%\t0.00\r\nKGS\t188336.22\tNOEXCISE\t0.00 %\t0.00\r\nEducational Cess on CVDs\t:\t0.00 %\t0.00\r\nSec & Higher Edu. Cess on CVD\t:\t0.00 %\t0.00\r\nCustoms Educational Cess\t:\t0.00 %\t0.00\r\nCustoms Sec & Higher Edu. Cess\t:\t0.00 %\t0.00\r\nSocial Welfare Surcharge:\t10.00 %\t1883.40\r\n', metadata={'source': 's3://my-s3-doc-loader/2667551.pdf', 'page': 1}),
#  Document(page_content='IGST GST Cess\r\n001/2017 III302\r\nRs.\r\n188336.22\r\n18.00 %\r\n37629.60\r\n001/2017 56\r\n0.00 %\r\n0.00\r\nPage Total\r\nRs.\r\n58346.60\r\nThis is an advance Customs Clearance document. The actual duty leviable may change with variations in statutory rates of duty/exchange rate. Re-assessment can also be made by the Customs Department under section 17 of the Customs Act 1962 any time before clearance.\r\nNIC ]\r\n1/ 7\r\nIndian Customs EDI System - Imports V1.5R001\r\nV1.5R001\r\nBILL OF ENTRY FOR HOME CONSUMPTION\r\n[Custom Stn: INMAA1]\tCHA : AGGPP7274BCH002 [SUPREME C & F SERVICES\t]\r\nBE No/Dt./cc/Typ:2667551/20/03/2024/N/H\r\nImporter Details 0798000066 PAN : AAACL2937JFT001\tAD Code : 0510010\r\nLIFE STYLE INTERNATIONAL PRIVATE LIMITED\r\nInv No & Dt. : IV2403-0231 07/03/2024\tBERGNER HK LIMITED\r\nItem Details\r\nslno RITC\tDescription\tRSP\tLoad PROV\r\nQty\tUnit Price\tCTH\tC.Notn C.NSNO\tCus Dty Rt\tBCD amt (Rs. )\r\nUnit\tAss Val\tCETH\tE. Notn E.NSNO\tExc Dty Rt\tCVD amt (Rs. )\r\n2\t82055190 SS23 S3 PEELERS MADE OF STAINLESS STEEL 44X43.5X26\r\n.5 CM HC 2590 MINT GREY\r\n1536.00\t1.050000\t82055190\t10.00 %\t13828.90\r\nCus AIDC\t011/2021 17\t0.00%\t0.00\r\nSET\t138288.83\tNOEXCISE\t0.00 %\t0.00\r\nEducational Cess on CVDs\t:\t0.00 %\t0.00\r\nSec & Higher Edu. Cess on CVD\t:\t0.00 %\t0.00\r\nCustoms Educational Cess\t:\t0.00 %\t0.00\r\nCustoms Sec & Higher Edu. Cess\t:\t0.00 %\t0.00\r\nSocial Welfare Surcharge:\t10.00 %\t1382.90\r\nIGST\t001/2017 III296\t18.00 %\t27630.10\r\nGST Cess\t001/2017 56\t0.00 %\t0.00\r\nRs.\t326625.05\tPage Total\tRs.\t101188.50\r\n\r\nThis is an advance Customs Clearance document. The actual duty leviable may change with variations in statutory rates of duty/exchange rate. Re-assessment can also be made by the Customs Department under section 17 of the Customs Act 1962 any time before clearance.\r\nNIC ]\r\n\r\n2/ 7\r\nIndian Customs EDI System - Imports V1.5R001', metadata={'source': 's3://my-s3-doc-loader/2667551.pdf', 'page': 2}),
#  Document(page_content='V1.5R001\r\n# BILL OF ENTRY FOR HOME CONSUMPTION\r\n[Custom Stn: INMAA1 CHA : AGGPP7274BCH002 [SUPREME C & F SERVICES ] BE o/Dt./cc/Typ:2667551/20/03/2024/N/H Importer Details :0798000066 PAN : AAACL2937JFT001 AD Code : 0510010 LIFE STYLE INTERNATIONAL PRIVATE LIMITED Inv No & Dt. : IV2403-0231 07/03/2024 BERGNER HK LIMITED Item Details\r\nslno RITC\tDescription\tRSP\tLoad PROV\r\nQty\tUnit Price\tCTH\tC.Notn C.NSNO\tCus Dty Rt\tBCD amt (Rs.)\r\nUnit\tAss Val\tCETH\tE.Notn E.NSNO\tExc Dty Rt\tCVD amt (Rs. )\r\n3\t82119200 PARING KNIFE TOTAL 1536 PCS USD 0.94 FOB PER PC MA\r\nDE OF STAINLESS STEEL 42X31.7X17 CM HC 2360\r\n134.40\t10.742857\t82119200\t10.00 %\t12380.10\r\nCus AIDC\t011/2021 17\t0.00%\t0.00\r\nKGS\t123801.42\tNOEXCISE\t0.00 %\t0.00\r\nEducational Cess on CVDs\t:\t0.00 %\t0.00\r\nSec & Higher Edu. Cess on CVD\t:\t0.00 %\t0.00\r\nCustoms Educational Cess\t:\t0.00 %\t0.00\r\nCustoms Sec & Higher Edu. Cess\t:\t0.00 %\t0.00\r\nSocial Welfare Surcharge:\t10.00 %\t1238.00\r\nIGST\t001/2017 III301A\t18.00 %\t24735.50\r\nGST Cess\t001/2017 56\t0.00 %\t0.00\r\nRs. 450426.47\tPage Total\tRs.\t139542.10\r\n\r\nThis is an advance Customs Clearance document. The actual duty leviable may change with variations in statutory rates of duty/exchange rate. Re-assessment can also be made by the Customs Department under section 17 of the Customs Act 1962 any time before clearance. [ NIC ] 3/ 7\r\n\r\nIndian Customs EDI System - Imports V1.5R001\r\nV1.5R001\r\n\r\nBILL OF ENTRY FOR HOME CONSUMPTION\r\n\r\n[Custom Stn: INMAA1]\r\n\r\nCHA : AGGPP7274BCH002 [SUPREME C & F SERVICES\r\n\r\n] BE No/Dt./cc/Typ:2667551/20/03/2024/N/H Importer Details :0798000066 PAN : AAACL2937JFT001\r\n\r\nAD Code : 0510010 LIFE STYLE INTERNATIONAL PRIVATE LIMITED\r\n\r\nInv No & Dt. : IV2403-0231 07/03/2024\r\n\r\nBERGNER HK LIMITED\r\n## Item Details\r\nslno RITC\tDescription\tRSP\tLoad PROV\r\nQty\tUnit Price\tCTH\tC. Notn C.NSNO\tCus Dty Rt\tBCD amt (Rs.)\r\nUnit\tAss Val\tCETH\tE. Notn E.NSNO\tExc Dty Rt\tCVD amt (Rs. )\r\n', metadata={'source': 's3://my-s3-doc-loader/2667551.pdf', 'page': 3}),
#  Document(page_content='4 82119200 UTILITY KNIFE TOTAL 1536 PCS USD 0.96 FOB PER PC M ADE OF STAINLESS STEEL 42X31.7X17 CM HC 2361\r\n140.80\t10.472727\t82119200\t10.00 %\t12643.50\r\nCus AIDC\t011/2021 17\t0.00%\t0.00\r\nKGS\t126435.49\tNOEXCISE\t0.00 %\t0.00\r\nEducational Cess on CVDs\t:\t0.00 %\t0.00\r\nSec & Higher Edu. Cess on CVD\t:\t0.00 %\t0.00\r\nCustoms Educational Cess\t:\t0.00 %\t0.00\r\nCustoms Sec & Higher Edu. Cess\t:\t0.00 %\t0.00\r\nSocial Welfare Surcharge:\t10.00 %\t1264.40\r\nIGST\t001/2017 III301A\t18.00 %\t25261.80\r\nGST Cess\t001/2017 56\t0.00 %\t0.00\r\nRs.\t576861.96\tPage Total\tRs.\t178711.80\r\n\r\nThis is an advance Customs Clearance document. The actual duty leviable may change with variations in statutory rates of duty/exchange rate. Re-assessment can also be made by the Customs Department under section 17 of the Customs Act 1962 any time before clearance.\r\nIndian Customs EDI System - Imports V1.5R001\r\nV1.5R001\r\nNIC ]\r\n4/ 7\r\nBILL OF ENTRY FOR HOME CONSUMPTION\r\n[Custom Stn: INMAA1] CHA : AGGPP7274BCH002 [SUPREME C & F SERVICES ] BE No/Dt./cc/Typ: 2667551/20/03/2024/N/H Importer Details : 0798000066 PAN : AAACL2937JFT001 AD Code : 0510010 LIFE STYLE INTERNATIONAL PRIVATE LIMITED Inv No & Dt. : IV2403-0231 07/03/2024 BERGNER HK LIMITED Item Details\r\nslno RITC\tDescription\tRSP\tLoad PROV\r\nQty\tUnit Price\tCTH\tC. Notn C.NSNO\tCus Dty Rt\tBCD amt (Rs.) )\r\nUnit\tAss Val\tCETH\tE. Notn E.NSNO\tExc Dty Rt\tCVD amt (Rs. )\r\n\r\n5\t82119200 SS21 KNIFE SHARPNER TOTAL 3000 PCS USD 0.97 FOB PE\r\nR PC MADEOF STAINLESS STEEL 37.5X22X30 CM HC 2315\r\n518.75\t5.609639\t82119200\t10.00 %\t24951.70\r\nCus AIDC\t011/2021 17\t0.00%\t0.00\r\nKGS\t249516.69\tNOEXCISE\t0.00 %\t0.00\r\nEducational Cess on\tCVDs\t:\t0.00 %\t0.00\r\nSec & Higher Edu. Cess on CVD\t:\t0.00 %\t0.00\r\nCustoms Educational Cess\t:\t0.00 %\t0.00\r\nCustoms Sec & Higher Edu. Cess\t:\t0.00 %\t0.00\r\nSocial Welfare Surcharge:\t10.00 %\t2495.20\r\nIGST\t001/2017 III301A\t18.00 %\t49853.40\r\nGST Cess\t001/2017 56\t0.00 %\t0.00\r\n', metadata={'source': 's3://my-s3-doc-loader/2667551.pdf', 'page': 4}),
#  Document(page_content='Rs.\r\n\r\n826378.65\r\nPage Total\r\nRs.\r\n\r\n256012.10\r\nThis is an advance Customs Clearance document. The actual duty leviable may change with variations in statutory rates of duty/exchange rate. Re-assessment can also be made by the Customs Department under section 17 of the Customs Act 1962 any time before clearance.\r\n5/ 7 Indian Customs EDI System - Imports V1.5R001\r\nV1.5R001\r\nNIC ]\r\nBILL OF ENTRY FOR HOME CONSUMPTION\r\n[Custom Stn: INMAA1] CHA : AGGPP7274BCH002 [SUPREME C & F SERVICES ] BE No/Dt./cc/Typ: 2667551/20/03/2024/N/H Importer Details 0798000066 PAN : AAACL2937JFT001 AD Code : 0510010 LIFE STYLE INTERNATIONAL PRIVATE LIMITED Inv No & Dt. : IV2403-0231 07/03/2024 BERGNER HK LIMITED Item Details\r\nslno RITC\tDescription\tRSP\tLoad PROV\r\nQty\tUnit Price\tCTH\tC.Notn C.NSNO\tCus Dty Rt\tBCD amt (Rs. )\r\nUnit\tAss Val\tCETH\tE. Notn E.NSNO\tExc Dty Rt\tCVD amt (Rs. )\r\n6\t82119200 S21 CHEF KNIFE TOTAL 3000 PCS USD 1.70 FOB PER PC\r\nMADE OF STAINLESS STEEL 44.5X21.5X18 CM HC 2364\r\n656.25\t7.771429\t82119200\t10.00 %\t43729.70\r\nCus AIDC\t011/2021 17\t0.00%\t0.00\r\nKGS\t437297.28\tNOEXCISE\t0.00 %\t0.00\r\nEducational Cess on CVDs\t:\t0.00 %\t0.00\r\nSec & Higher Edu. Cess on CVD\t:\t0.00 %\t0.00\r\nCustoms Educational Cess\t:\t0.00 %\t0.00\r\nCustoms Sec & Higher Edu. Cess\t:\t0.00 %\t0.00\r\nSocial Welfare Surcharge:\t10.00 %\t4373.00\r\nIGST\t001/2017 III301A\t18.00 %\t87372.00\r\nGST Cess\t001/2017 56\t0.00 %\t0.00\r\nRs. 1263675.93\tPage Total\tRs.\t391486.80\r\n\r\nThis is an advance Customs Clearance document. The actual duty leviable may change with variations in statutory rates of duty/exchange rate. Re-assessment can also be made by the Customs Department under section 17 of the Customs Act 1962 any time before clearance. NIC ]\r\n6/ 7\r\nIndian Customs EDI System - Imports V1.5R001\r\nV1.5R001\r\nBILL OF ENTRY FOR HOME CONSUMPTION', metadata={'source': 's3://my-s3-doc-loader/2667551.pdf', 'page': 5}),
#  Document(page_content=']\r\n[Custom Stn: INMAA1]\r\nCHA : AGGPP7274BCH002 [SUPREME C & F SERVICES\r\nBE No/Dt./cc/Typ: 2667551/20/03/2024/N/H\r\nImporter Details 0798000066 PAN : AAACL2937JFT001\r\nLIFE STYLE INTERNATIONAL PRIVATE LIMITED\r\nInv No & Dt. : IV2403-0231 07/03/2024\r\nItem Details\r\nslno RITC\tDescription\tRSP\tLoad PROV\r\nQty\tUnit Price\tCTH\tC. Notn C.NSNO\tCus Dty Rt\tBCD amt (Rs. )\r\nUnit\tAss Val\tCETH\tE. Notn E.NSNO\tExc Dty Rt\tCVD amt (Rs. )\r\n7\t82119200 SS21 8 PC ROTATING KNIFE SET TOTAL 1500 PCS USD 10\r\n.9 FOB PERPC MADE OF STAINLESS STEEL 54.5X35.5X41 CM HC 2352\r\n2592.50\t6.306654\t82119200\t10.00 %\t140192.40\r\nCus AIDC\t011/2021 17\t0.00%\t0.00\r\nKGS\t1401923.60\tNOEXCISE\t0.00 %\t0.00\r\nEducational Cess on CVDs\t:\t0.00 %\t0.00\r\nSec & Higher Edu. Cess on CVD\t:\t0.00 %\t0.00\r\nCustoms Educational Cess\t:\t0.00 %\t0.00\r\nCustoms Sec & Higher Edu. Cess\t:\t0.00 %\t0.00\r\nSocial Welfare Surcharge:\t10.00 %\t14019.20\r\nIGST\t001/2017 III301A\t18.00 %\t280104.31\r\nGST Cess\t001/2017 56\t0.00 %\t0.00\r\nRs.\t2665599.53\tPage Total\tRs.\t825802.70\r\nRs.\t2665599.53\tInv. Gross Total\tRs.\t825802.70\r\nRs.\t2665599.53\tBE Gross Total\tRs.\t825802.70\r\nBCD\tRs.\t266559.90\tNCD Duty\tRs.\t0.00\r\nANTID\tRs.\t0.00\tSAFEGUARD Duty\tRs.\t0.00\r\nCVD\tRs.\t0.00\tSch 2 Spl Excise Duty\tRs.\t0.00\r\nCESS\tRs.\t0.00\tGSIA\tRs.\t0.00\r\nTTA\tRs.\t0.00\r\nEdu. Cess CVD\tRs.\t0.00\tCustoms Edu. Cess\tRs.\t0.00\r\nHealth CVD\tRs.\t0.00\tAddl Duty - (Imports)\tRs.\t0.00\r\nSHE. Cess CVD\tRs.\t0.00\tSH Cust Edu. Cess\tRs.\t0.00\r\nDuty Payable:\tRs.\t825803\r\nRs. Eight Lakh Twenty Five Thousand Eight Hundred and Three only\r\n\r\n## Container Details\r\n1 2371888 F SEGU1330114\r\nGSTIN Details\r\nAD Code : 0510010\r\nBERGNER HK LIMITED\r\nDocument No\tTyp State Cd/Name\tIGST Ass.val\tIGST Amt\tGST Cess Amt\r\n-\r\n33AAACL2937J1ZL\tG 33 Tamil Nadu\t2958815\t532587\t0\r\n', metadata={'source': 's3://my-s3-doc-loader/2667551.pdf', 'page': 6}),
#  Document(page_content='This is an advance Customs Clearance document. The actual duty leviable may change with variations in statutory rates of duty/exchange rate. Re-assessment can also be made by the Customs Department under section 17 of the Customs Act 1962 any time before clearance.\r\n7/7\r\n[ NIC ]', metadata={'source': 's3://my-s3-doc-loader/2667551.pdf', 'page': 7})]

# %%
all_page_content = ""

for doc in docs:
    all_page_content += doc.page_content

print(all_page_content)

# %%
all_page_content
# Out:
# 'Indian Customs EDI System - Imports V1.5R001\r\nV1.5R001\r\n# BILL OF ENTRY FOR HOME CONSUMPTION\r\n[Custom Stn: INMAA1 CHA : AGGPP7274BCH002 [SUPREME C & F SERVICES ] BE No/Dt./cc/Typ: 2667551/20/03/2024/N/H Importer Details :0798000066 PAN : AAACL2937JFT001 AD Code : 0510010 LIFE STYLE INTERNATIONAL PRIVATE LIMITED 14 : CHENNAI IMPORT WAREHOUSE NO.31/1, POOCHIATHIPET VILLAGE OFF REDHILLS, THIRUVALLUVAR RD REDHILLS CHENNAI 600052 Payment Method : Transaction\r\nIGM No : 2371888/19/03/2024 Cntry of Orgn : CHINA BL No : SZXCB24007583 Date : 08/03/2024 No. of Pkgs. : 628 CTN Marks:AS PER BL & Nos\r\nPort of Loading : Shekou Cntry of Consgn.: H/BL No : RSJ2402518 Date : 08/03/2024 Gross Wt. : 4807.900 KGS\r\nInv No & Dt. : IV2403-0231 07/03/2024 BERGNER HK LIMITED Inv Val : 31087.68 USD TOI: FOB 48/F LANGHAM PLACE OFFICE TOWER 8 Freight : 61975.00 INR ARGYLE ST MONG KOK Insurance : 0.001200% 0.00 HONG KONG SVB Load (Ass) : Cust. House: HK SVB Load (Dty) : HSS Load Rate: 0.00% Amount: 0.00 Misc. Charges: 0.00 0.00 Discount Rate: 0.00 Discount Amount: 0.00 EDD : 0.00 XBE Duty FG Int.: 0.00 Third Party:\r\nBuyerSeller Reltd : No Item Details Exchange rate: 1.00 USD = 83.7500 INR\r\nSlno RITC\tDescription\tRSP\tLoad PROV\r\nQty\tUnit Price\tCTH\tC.Notn C.NSNO\tCus Dty Rt\tBCD amt (Rs)\r\nUnit\tAss Val\tCETH\tE.Notn E.NSNO\tExc Dty Rt\tCVD amt (Rs)\r\n1\t82130000 SS23 S3 KITCHEN SCISSORS TOTAL 1536 SETS USD 1.43\r\nFOB PER SET MADE OF STAINLESS STEEL 37.5X33.5X37.5CM HC 2589\r\n294.40\t7.460870\t82130000\t10.00 %\t18833.60\r\nCus AIDC\t011/2021 17\t0.00%\t0.00\r\nKGS\t188336.22\tNOEXCISE\t0.00 %\t0.00\r\nEducational Cess on CVDs\t:\t0.00 %\t0.00\r\nSec & Higher Edu. Cess on CVD\t:\t0.00 %\t0.00\r\nCustoms Educational Cess\t:\t0.00 %\t0.00\r\nCustoms Sec & Higher Edu. Cess\t:\t0.00 %\t0.00\r\nSocial Welfare Surcharge:\t10.00 %\t1883.40\r\nIGST GST Cess\r\n001/2017 III302\r\nRs.\r\n188336.22\r\n18.00 %\r\n37629.60\r\n001/2017 56\r\n0.00 %\r\n0.00\r\nPage Total\r\nRs.\r\n58346.60\r\nThis is an advance Customs Clearance document. The actual duty leviable may change with variations in statutory rates of duty/exchange rate. Re-assessment can also be made by the Customs Department under section 17 of the Customs Act 1962 any time before clearance.\r\nNIC ]\r\n1/ 7\r\nIndian Customs EDI System - Imports V1.5R001\r\nV1.5R001\r\nBILL OF ENTRY FOR HOME CONSUMPTION\r\n[Custom Stn: INMAA1]\tCHA : AGGPP7274BCH002 [SUPREME C & F SERVICES\t]\r\nBE No/Dt./cc/Typ:2667551/20/03/2024/N/H\r\nImporter Details 0798000066 PAN : AAACL2937JFT001\tAD Code : 0510010\r\nLIFE STYLE INTERNATIONAL PRIVATE LIMITED\r\nInv No & Dt. : IV2403-0231 07/03/2024\tBERGNER HK LIMITED\r\nItem Details\r\nslno RITC\tDescription\tRSP\tLoad PROV\r\nQty\tUnit Price\tCTH\tC.Notn C.NSNO\tCus Dty Rt\tBCD amt (Rs. )\r\nUnit\tAss Val\tCETH\tE. Notn E.NSNO\tExc Dty Rt\tCVD amt (Rs. )\r\n2\t82055190 SS23 S3 PEELERS MADE OF STAINLESS STEEL 44X43.5X26\r\n.5 CM HC 2590 MINT GREY\r\n1536.00\t1.050000\t82055190\t10.00 %\t13828.90\r\nCus AIDC\t011/2021 17\t0.00%\t0.00\r\nSET\t138288.83\tNOEXCISE\t0.00 %\t0.00\r\nEducational Cess on CVDs\t:\t0.00 %\t0.00\r\nSec & Higher Edu. Cess on CVD\t:\t0.00 %\t0.00\r\nCustoms Educational Cess\t:\t0.00 %\t0.00\r\nCustoms Sec & Higher Edu. Cess\t:\t0.00 %\t0.00\r\nSocial Welfare Surcharge:\t10.00 %\t1382.90\r\nIGST\t001/2017 III296\t18.00 %\t27630.10\r\nGST Cess\t001/2017 56\t0.00 %\t0.00\r\nRs.\t326625.05\tPage Total\tRs.\t101188.50\r\n\r\nThis is an advance Customs Clearance document. The actual duty leviable may change with variations in statutory rates of duty/exchange rate. Re-assessment can also be made by the Customs Department under section 17 of the Customs Act 1962 any time before clearance.\r\nNIC ]\r\n\r\n2/ 7\r\nIndian Customs EDI System - Imports V1.5R001V1.5R001\r\n# BILL OF ENTRY FOR HOME CONSUMPTION\r\n[Custom Stn: INMAA1 CHA : AGGPP7274BCH002 [SUPREME C & F SERVICES ] BE o/Dt./cc/Typ:2667551/20/03/2024/N/H Importer Details :0798000066 PAN :  ...

# %%
template = """
    Must convert datas into JSON format

    Instructions:
        - Do not skip any datas while converting into JSON
        - I need all the datas to be in JSON format
        - Avoid mismatching of the datas

    
{datas}
"""

# %%
qa_prompt = PromptTemplate(template=template, input_variables=["datas"])
llm = Bedrock(model_id="anthropic.claude-v2:1",client=bedrock_client,model_kwargs = {"temperature":1e-10,"max_tokens_to_sample": 40000})
llm_chain = LLMChain(prompt=qa_prompt, llm=llm, verbose= False)
result = llm_chain.run(datas= all_page_content)
print(result)
# Out:
#  Here is the JSON format of the given data:
#
# ```json
# {
#   "CustomsStation": "INMAA1",
#   "CHA": "AGGPP7274BCH002",
#   "CHAName": "SUPREME C & F SERVICES",
#   "BENumber": "2667551",
#   "BEDate": "20/03/2024",
#   "BEType": "N/H",
#   "ImporterDetails": {
#     "ImporterCode": "0798000066",
#     "PAN": "AAACL2937JFT001",
#     "ADCode": "0510010"
#   },
#   "ImporterName": "LIFE STYLE INTERNATIONAL PRIVATE LIMITED",
#   "InvoiceDetails": {
#     "Number": "IV2403-0231",
#     "Date": "07/03/2024"
#   },
#   "ExporterName": "BERGNER HK LIMITED",
#   "IGMNumber": "2371888",
#   "IGMDate": "19/03/2024",
#   "CountryOfOrigin": "CHINA",
#   "BillOfLadingNumber": "SZXCB24007583",
#   "BillOfLadingDate": "08/03/2024",
#   "NumberOfPackages": 628,
#   "ContainerMarks": "AS PER BL & Nos",
#   "PortOfLoading": "Shekou",
#   "CountryOfConsignment": "H/BL",
#   "HouseBillOfLadingNumber": "RSJ2402518",
#   "HouseBillOfLadingDate": "08/03/2024",
#   "GrossWeight": 4807.9,
#   "InvoiceValueCurrency": "USD",
#   "InvoiceValue": 31087.68,
#   "TermsOfShipment": "FOB",
#   "FreightAmount": 61975,
#   "InsuranceAmount": 0.001200,
#   "SVBLoadingCharges": "Cust. House: HK SVB Load (Dty)",
#   "HSSLoadingRate": 0,
#   "HSSLoadingAmount": 0,
#   "MiscellaneousCharges": 0,
#   "DiscountRate": 0,
#   "DiscountAmount": 0,
#   "EDD": 0,
#   "XBEDutyFGInt": 0,
#   "ThirdPartyDetails": null,
#   "BuyerSellerRelated": "No",
#   "ExchangeRate": 83.75,
#   "ItemDetails": [
#     {
#       "SerialNo": 1,
#       "RITCCode": "82130000",
#       "Description": "SS23 S3 KITCHEN SCISSORS TOTAL 1536 SETS USD 1.43 FOB PER SET MADE OF STAINLESS STEEL 37.5X33.5X37.5CM HC 2589",
#       "Quantity": 294.4,
#       "UnitPrice": 7.460870,
#       "CustomsTariffHeading": "82130000",
#       "CustomsNotification": "10.00 %",
#       "BasicCustomsDutyRate": 18833.6,
#       "BasicCustomsDutyAmount": 0,
#       "Unit": "KGS",
#       "AssessableValue": 188336.22,
#       "CentralExciseTariffHeading": "NOEXCISE",
#       "ExciseDutyRate": "0.00 %",
#       "ExciseDutyAmount": 0,
#       "EducationCessOnCVD": 0,
#       "SecondaryHigherEducationCessOnCVD": 0,
#       "CustomsEducationCess": 0,
#       "CustomsSecondaryHigherEducationCess": 0,
#       "SocialWelfareSurcharge": 1883.4,
#       "IntegratedGSTRate": "18.00 %",
#       "IntegratedGSTAmount": 37629.6,
#       "GSTCessRate": "0.00 %",
#       "GSTCessAmount": 0,
#       "PageTotal": 58346.6
#     },
#     {
#       "SerialNo": 2,
#       "RITCCode": "82055190",
#       "Description": "SS23 S3 PEELERS MADE OF STAINLESS STEEL 44X43.5X26.5 CM HC 2590 MINT GREY",
#       "Quantity": 1536,
#       "UnitPrice": 1.050000,
#       "CustomsTariffHeading": "82055190",
#       "CustomsNotification": "10.00 %",
#       "BasicCustomsDutyRate": 13828.9,
#       "BasicCustomsDutyAmount": 0,
#       "Unit": "SET",
#       "AssessableValue": 138288.83,
#       "CentralExciseTariffHeading": "NOEXCISE",
#       "ExciseDutyRate": "0.00 %",
#       "ExciseDutyAmount": 0,
#       "EducationCessOnCVD": 0,
#       "SecondaryHigherEducationCessOnCVD": 0,
#       "CustomsEducationCess": 0,
#       "CustomsSecondaryHigherEducationCess": 0,
#       "SocialWelfareSurcharge": 1382.9,
#       "IntegratedGSTRate": "18.00 %",
#       "IntegratedGSTAmount": 27630.1,
#       "GSTCessRate": "0.00 %",
#       "GSTCessAmount": 0,
#       "PageTotal": 101188.5
#     },
#     {
#       "SerialNo": 3,
#       "RITCCode": "82119200",
#       "Description": "PARING KNIFE TOTAL 1536 PCS USD 0.94 FOB PER PC MA DE OF STAINLESS STEEL 42X31.7X17 CM HC 2360",
#       "Quantity": 134.4,
#       "UnitPrice": 10.742857,
#       "CustomsTariffHeading": "82119200",
#       "CustomsNotification": "10.00 %",
#       "BasicCustomsDutyRate": 12380.1,
#       "BasicCustomsDutyAmount": 0,
#       "Unit": "KGS",
#       "AssessableValue": 123801.42,
#       "CentralExciseTariffHeading": "NOEXCISE",
#       "ExciseDutyRate": "0.00 %",
#       "ExciseDutyAmount": 0,
#       "EducationCessOnCVD": 0,
#       "SecondaryHigherEducationCessOnCVD": 0,
#       "CustomsEducationCess": 0,
#       "CustomsSecondaryHigherEducationCess": 0,
#       "SocialWelfareSurcharge": 1238,
#       "IntegratedGSTRate": "18.00 %",
#       "IntegratedGSTAmount": 24735.5,
#       "GSTCessRate": "0.00 %",
#       "GSTCessAmount": 0,
#       "PageTotal": 139542.1
#     },
#     {
#       "SerialNo": 4,
#       "RITCCode": "82119200",
#       "Description": "UTILITY KNIFE TOTAL 1536 PCS USD 0.96 FOB PER PC M ADE OF STAINLESS STEEL 42X31.7X17 CM HC 2361",
#       "Quantity": 140.8,
#       "UnitPrice": 10.472727,
#       "CustomsTariffHeading": "82119200",
#       "CustomsNotification": "10.00 %",
#       "BasicCustomsDutyRate": 12643.5,
#       "BasicCustomsDutyAmount": 0,
#       "Unit": "KGS",
#       "AssessableValue": 126435.49,
#       "CentralExciseTariffHeading": "NOEXCISE",
#       "ExciseDutyRate": "0.00 %",
#       "ExciseDutyAmount": 0,
#       "EducationCessOnCVD": 0,
#       "SecondaryHigherEducationCessOnCVD": 0,
#       "CustomsEducationCess": 0,
#       "CustomsSecondaryHigherEducationCess": 0,
#       "SocialWelfareSurcharge": 1264.4,
#       "IntegratedGSTRate": "18.00 %",
#       "IntegratedGSTAmount": 25261.8,
#       "GSTCessRate": "0.00 %",
#       "GSTCessAmount": 0,
#       "PageTotal": 178711.8
#     },
#     {
#       "SerialNo": 5,
#       "RITCCode": "82119200",
#       "Description": "SS21 KNIFE SHARPNER TOTAL 3000 PCS USD 0.97 FOB PE R PC MADEOF STAINLESS STEEL 37.5X22X30 CM HC 2315",
#       "Quantity": 518.75,
#       "UnitPrice": 5.609639,
#       "CustomsTariffHeading": "82119200",
#       "CustomsNotification": "10.00 %",
#       "BasicCustomsDutyRate": 24951.7,
#       "BasicCustomsDutyAmount": 0,
#       "Unit": "KGS",
#       "AssessableValue": 249516.69,
#       "CentralExciseTariffHeading": "NOEXCISE",
#       "ExciseDutyRate": "0.00 %",
#       "ExciseDutyAmount": 0,
#       "EducationCessOnCVD": 0,
#       "SecondaryHigherEducationCessOnCVD": 0,
#       "CustomsEducationCess": 0,
#       "CustomsSecondaryHigherEducationCess": 0,
#       "SocialWelfareSurcharge": 2495.2,
#       "IntegratedGSTRate": "18.00 %",
#       "IntegratedGSTAmount": 49853.4,
#       "GSTCessRate": "0.00 %",
#       "GSTCessAmount": 0,
#       "PageTotal": 256012.1
#     },
#     {
#       "SerialNo": 6,
#       "RITCCode": "82119200",
#       "Description": "S21 CHEF KNIFE TOTAL 3000 PCS USD 1.70 FOB PER PC MADE OF STAINLESS STEEL 44.5X21.5X18 CM HC 2364",
#       "Quantity": 656.25,
#       "UnitPrice": 7.771429,
#       "CustomsTariffHeading": "82119200",
#       "CustomsNotification": "10.00 %",
#       "BasicCustomsDutyRate": 43729.7,
#       "BasicCustomsDutyAmount": 0,
#       "Unit": "KGS",
#       "AssessableValue": 437297.28,
#       "CentralExciseTariffHeading": "NOEXCISE",
#       "ExciseDutyRate": "0.00 %",
#       "ExciseDutyAmount": 0,
#       "EducationCessOnCVD": 0,
#       "SecondaryHigherEducationCessOnCVD": 0,
#       "CustomsEducationCess": 0,
#       "CustomsSecondaryHigherEducationCess": 0,
#       "SocialWelfareSurcharge": 4373,
#       "IntegratedGSTRate": "18.00 %",
#       "IntegratedGSTAmount": 87372,
#       "GSTCessRate": "0.00 %",
#       "GSTCessAmount": 0,
#       "PageTotal": 391486.8
#     },
#     {
#       "SerialNo": 7,
#       "RITCCode": "82119200",
#       "Description": "SS21 8 PC ROTATING KNIFE SET TOTAL 1500 PCS USD 10 .9 FOB PERPC MADE OF STAINLESS STEEL 54.5X35.5X41 CM HC 2352",
#       "Quantity": 2592.5,
#       "UnitPrice": 6.306654,
#       "CustomsTariffHeading": "82119200",
#       "CustomsNotification": "10.00 %",
#       "BasicCustomsDutyRate": 140192.4,
#       "BasicCustomsDutyAmount": 0,
#       "Unit": "KGS",
#       "AssessableValue": 1401923.6,
#       "CentralExciseTariffHeading": "NOEXCISE",
#       "ExciseDutyRate": "0.00 %",
#       "ExciseDutyAmount": 0,
#       "EducationCessOnCVD": 0,
#       "SecondaryHigherEducationCessOnCVD": 0,
#       "CustomsEducationCess": 0,
#       "CustomsSecondaryHigherEducationCess": 0,
#       "SocialWelfareSurcharge": 14019.2,
#       "IntegratedGSTRate": "18.00 %",
#       "IntegratedGSTAmount": 280104.31,
#       "GSTCessRate": "0.00 %",
#       "GSTCessAmount": 0,
#       "PageTotal": 825802.7
#     }
#   ],
#   "ContainerDetails": [
#     {
#       "IGMNumber": "2371888",
#       "ContainerCategory": "F",
#       "ContainerNumber": "SEGU1330114"
#     }
#   ],
#   "GSTINDetails": {
#     "ADCode": "0510010",
#     "GSTIN": "33AAACL2937J1ZL",
#     "StateCode": 33,
#     "StateName": "Tamil Nadu",
#     "IGSTAssessableValue": 2958815,
#     "IGSTAmount": 532587,
#     "GSTCessAmount": 0
#   },
#   "InvoiceGrossTotal": 825802.7,
#   "BEGrossTotal": 825802.7,
#   "DutyBreakup": {
#     "BCD": 266559.9,
#     "NCDDuty": 0,
#     "ANTID": 0,
#     "SafeguardDuty": 0,
#     "CVD": 0,
#     "CESS": 0,
#     "TTA": 0,
#     "EducationCessCVD": 0,
#     "CustomsEducationCess": 0,
#     "HealthCVD": 0,
#     "SHECessCVD": 0,
#     "AdditionalDutyImports": 0,
#     "SecondaryHigherEducationCess": 0,
#     "DutyPayable": 825803
#   },
#   "DutyPayableInWords": "Eight Lakh Twenty Five Thousand Eight Hundred and Three only"
# }
# ```
#
# I have converted all the data into JSON format without skipping any fields. Let me know if you need any changes.
