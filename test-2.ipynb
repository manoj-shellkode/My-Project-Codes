# %%
from langchain_community.document_loaders import AmazonTextractPDFLoader
from langchain_community.document_loaders import PDFPlumberLoader
from langchain.prompts import PromptTemplate
from langchain.llms.bedrock import Bedrock
from langchain.chains import LLMChain
import boto3
import botocore

config = botocore.config.Config(
    read_timeout=900,
    connect_timeout=900,
    retries={"max_attempts": 3}
)

bedrock_client = boto3.client(
    service_name="bedrock-runtime",
    region_name="us-east-1",
    config=config,
)

textract_client = boto3.client("textract", region_name="us-west-2")
textract_features=["LAYOUT"]
file_path = r"s3://my-s3-doc-loader/2667551.pdf"
loader = AmazonTextractPDFLoader(file_path,textract_features,client=textract_client)
docs = loader.load()

# %%
all_page_content = ""

for doc in docs:
    all_page_content += doc.page_content

# print(all_page_content)

# %%
template = """
    Must convert datas into JSON format

    Instructions:
        - Do not skip any datas while converting into JSON
        - I need all the datas to be in JSON format
        - Avoid mismatching of the datas
    
    Important Instructions:
        - Strictly print all the terms like as it is in the document while converting JSON, Do not make abbreviation on your own for all the text
        

    
{datas}
"""

# %%
qa_prompt = PromptTemplate(template=template, input_variables=["datas"])
llm = Bedrock(model_id="anthropic.claude-v2:1",client=bedrock_client,model_kwargs = {"temperature":1e-10,"max_tokens_to_sample": 40000})
llm_chain = LLMChain(prompt=qa_prompt, llm=llm, verbose= False)
result = llm_chain.run(datas= all_page_content)
print(result)
# Out:
#  Here is the JSON format of the given document:
#
# ```json
# {
#     "document_name": "Indian Customs EDI System - Imports",
#     "document_version": "V1.5R001",
#     "bill_of_entry_type": "BILL OF ENTRY FOR HOME CONSUMPTION",
#     "customs_station": "INMAA1",
#     "cha_details": "AGGPP7274BCH002 [SUPREME C & F SERVICES ]",
#     "bill_of_entry_details": {
#         "be_number": "2667551",
#         "be_date": "20/03/2024",
#         "be_type": "N/H"
#     },
#     "importer_details": {
#         "iec_code": "0798000066",
#         "pan": "AAACL2937JFT001",
#         "ad_code": "0510010",
#         "name": "LIFE STYLE INTERNATIONAL PRIVATE LIMITED",
#         "address": "14 : CHENNAI IMPORT WAREHOUSE NO.31/1, POOCHIATHIPET VILLAGE OFF REDHILLS, THIRUVALLUVAR RD REDHILLS CHENNAI 600052"
#     },
#     "payment_method": "Transaction",
#     "igm_details": {
#         "igm_number": "2371888/19/03/2024",
#         "country_of_origin": "CHINA",
#         "bill_of_lading_number": "SZXCB24007583",
#         "bill_of_lading_date": "08/03/2024",
#         "number_of_packages": "628",
#         "container_marks": "AS PER BL & Nos"
#     },
#     "port_of_loading": "Shekou",
#     "country_of_consignment": "H",
#     "house_bill_of_lading_number": "RSJ2402518",
#     "house_bill_of_lading_date": "08/03/2024",
#     "gross_weight": "4807.900 KGS",
#     "invoice_details": {
#         "invoice_number": "IV2403-0231",
#         "invoice_date": "07/03/2024",
#         "supplier_name": "BERGNER HK LIMITED",
#         "invoice_value": "31087.68 USD",
#         "invoice_value_terms": "FOB 48/F LANGHAM PLACE OFFICE TOWER 8 ARGYLE ST MONG KOK HONG KONG"
#     },
#     "freight": "61975.00 INR",
#     "insurance": "0.001200% 0.00",
#     "svb_load_assessed": "Cust. House: HK SVB Load (Ass)",
#     "svb_load_duty": "HSS Load (Dty)",
#     "load_rate": "0.00%",
#     "load_amount": "0.00",
#     "miscellaneous_charges": "0.00",
#     "discount_rate": "0.00",
#     "discount_amount": "0.00",
#     "exchange_delivery_difference": "0.00",
#     "exchange_benefit_intervention": "0.00",
#     "third_party": null,
#     "buyer_seller_relationship": "No",
#     "exchange_rate": {
#         "currency": "USD",
#         "rate": "83.7500 INR"
#     },
#     "item_details": [
#         {
#             "serial_number": "1",
#             "ritc_code": "82130000",
#             "description": "SS23 S3 KITCHEN SCISSORS TOTAL 1536 SETS USD 1.43 FOB PER SET MADE OF STAINLESS STEEL 37.5X33.5X37.5CM HC 2589",
#             "quantity": "294.40",
#             "unit_price": "7.460870",
#             "customs_tariff_heading": "82130000",
#             "customs_notification": "10.00 %",
#             "basic_customs_duty_rate": "18833.60",
#             "basic_customs_duty_notification": "011/2021 17",
#             "basic_customs_duty_amount": "0.00",
#             "unit": "KGS",
#             "assessed_value": "188336.22",
#             "central_excise_tariff_heading": "NOEXCISE",
#             "excise_duty_rate": "0.00 %",
#             "excise_duty_amount": "0.00",
#             "education_cess_on_cvd": "0.00 %",
#             "secondary_higher_education_cess_on_cvd": "0.00 %",
#             "customs_education_cess": "0.00 %",
#             "customs_secondary_higher_education_cess": "0.00 %",
#             "social_welfare_surcharge": "10.00 %",
#             "social_welfare_surcharge_amount": "1883.40",
#             "igst_details": {
#                 "igst_notification": "001/2017 III302",
#                 "integrated_gst_rate": "18.00 %",
#                 "integrated_gst_amount": "37629.60"
#             },
#             "gst_cess_details": {
#                 "gst_cess_notification": "001/2017 56",
#                 "gst_cess_rate": "0.00 %",
#                 "gst_cess_amount": "0.00"
#             },
#             "page_total": "58346.60"
#         },
#         {
#             "serial_number": "2",
#             "ritc_code": "82055190",
#             "description": "SS23 S3 PEELERS MADE OF STAINLESS STEEL 44X43.5X26.5 CM HC 2590 MINT GREY",
#             "quantity": "1536.00",
#             "unit_price": "1.050000",
#             "customs_tariff_heading": "82055190",
#             "customs_notification": "10.00 %",
#             "basic_customs_duty_rate": "13828.90",
#             "basic_customs_duty_notification": "011/2021 17",
#             "basic_customs_duty_amount": "0.00",
#             "unit": "SET",
#             "assessed_value": "138288.83",
#             "central_excise_tariff_heading": "NOEXCISE",
#             "excise_duty_rate": "0.00 %",
#             "excise_duty_amount": "0.00",
#             "education_cess_on_cvd": "0.00 %",
#             "secondary_higher_education_cess_on_cvd": "0.00 %",
#             "customs_education_cess": "0.00 %",
#             "customs_secondary_higher_education_cess": "0.00 %",
#             "social_welfare_surcharge": "10.00 %",
#             "social_welfare_surcharge_amount": "1382.90",
#             "igst_details": {
#                 "igst_notification": "001/2017 III296",
#                 "integrated_gst_rate": "18.00 %",
#                 "integrated_gst_amount": "27630.10"
#             },
#             "gst_cess_details": {
#                 "gst_cess_notification": "001/2017 56",
#                 "gst_cess_rate": "0.00 %",
#                 "gst_cess_amount": "0.00"
#             },
#             "page_total": "101188.50"
#         },
#         {
#             "serial_number": "3",
#             "ritc_code": "82119200",
#             "description": "PARING KNIFE TOTAL 1536 PCS USD 0.94 FOB PER PC MA DE OF STAINLESS STEEL 42X31.7X17 CM HC 2360",
#             "quantity": "134.40",
#             "unit_price": "10.742857",
#             "customs_tariff_heading": "82119200",
#             "customs_notification": "10.00 %",
#             "basic_customs_duty_rate": "12380.10",
#             "basic_customs_duty_notification": "011/2021 17",
#             "basic_customs_duty_amount": "0.00",
#             "unit": "KGS",
#             "assessed_value": "123801.42",
#             "central_excise_tariff_heading": "NOEXCISE",
#             "excise_duty_rate": "0.00 %",
#             "excise_duty_amount": "0.00",
#             "education_cess_on_cvd": "0.00 %",
#             "secondary_higher_education_cess_on_cvd": "0.00 %",
#             "customs_education_cess": "0.00 %",
#             "customs_secondary_higher_education_cess": "0.00 %",
#             "social_welfare_surcharge": "10.00 %",
#             "social_welfare_surcharge_amount": "1238.00",
#             "igst_details": {
#                 "igst_notification": "001/2017 III301A",
#                 "integrated_gst_rate": "18.00 %",
#                 "integrated_gst_amount": "24735.50"
#             },
#             "gst_cess_details": {
#                 "gst_cess_notification": "001/2017 56",
#                 "gst_cess_rate": "0.00 %",
#                 "gst_cess_amount": "0.00"
#             },
#             "page_total": "139542.10"
#         },
#         {
#             "serial_number": "4",
#             "ritc_code": "82119200",
#             "description": "UTILITY KNIFE TOTAL 1536 PCS USD 0.96 FOB PER PC M ADE OF STAINLESS STEEL 42X31.7X17 CM HC 2361",
#             "quantity": "140.80",
#             "unit_price": "10.472727",
#             "customs_tariff_heading": "82119200",
#             "customs_notification": "10.00 %",
#             "basic_customs_duty_rate": "12643.50",
#             "basic_customs_duty_notification": "011/2021 17",
#             "basic_customs_duty_amount": "0.00",
#             "unit": "KGS",
#             "assessed_value": "126435.49",
#             "central_excise_tariff_heading": "NOEXCISE",
#             "excise_duty_rate": "0.00 %",
#             "excise_duty_amount": "0.00",
#             "education_cess_on_cvd": "0.00 %",
#             "secondary_higher_education_cess_on_cvd": "0.00 %",
#             "customs_education_cess": "0.00 %",
#             "customs_secondary_higher_education_cess": "0.00 %",
#             "social_welfare_surcharge": "10.00 %",
#             "social_welfare_surcharge_amount": "1264.40",
#             "igst_details": {
#                 "igst_notification": "001/2017 III301A",
#                 "integrated_gst_rate": "18.00 %",
#                 "integrated_gst_amount": "25261.80"
#             },
#             "gst_cess_details": {
#                 "gst_cess_notification": "001/2017 56",
#                 "gst_cess_rate": "0.00 %",
#                 "gst_cess_amount": "0.00"
#             },
#             "page_total": "178711.80"
#         },
#         {
#             "serial_number": "5",
#             "ritc_code": "82119200",
#             "description": "SS21 KNIFE SHARPNER TOTAL 3000 PCS USD 0.97 FOB PE R PC MADEOF STAINLESS STEEL 37.5X22X30 CM HC 2315",
#             "quantity": "518.75",
#             "unit_price": "5.609639",
#             "customs_tariff_heading": "82119200",
#             "customs_notification": "10.00 %",
#             "basic_customs_duty_rate": "24951.70",
#             "basic_customs_duty_notification": "011/2021 17",
#             "basic_customs_duty_amount": "0.00",
#             "unit": "KGS",
#             "assessed_value": "249516.69",
#             "central_excise_tariff_heading": "NOEXCISE",
#             "excise_duty_rate": "0.00 %",
#             "excise_duty_amount": "0.00",
#             "education_cess_on_cvd": "0.00 %",
#             "secondary_higher_education_cess_on_cvd": "0.00 %",
#             "customs_education_cess": "0.00 %",
#             "customs_secondary_higher_education_cess": "0.00 %",
#             "social_welfare_surcharge": "10.00 %",
#             "social_welfare_surcharge_amount": "2495.20",
#             "igst_details": {
#                 "igst_notification": "001/2017 III301A",
#                 "integrated_gst_rate": "18.00 %",
#                 "integrated_gst_amount": "49853.40"
#             },
#             "gst_cess_details": {
#                 "gst_cess_notification": "001/2017 56",
#                 "gst_cess_rate": "0.00 %",
#                 "gst_cess_amount": "0.00"
#             },
#             "page_total": "256012.10"
#         },
#         {
#             "serial_number": "6",
#             "ritc_code": "82119200",
#             "description": "S21 CHEF KNIFE TOTAL 3000 PCS USD 1.70 FOB PER PC MADE OF STAINLESS STEEL 44.5X21.5X18 CM HC 2364",
#             "quantity": "656.25",
#             "unit_price": "7.771429",
#             "customs_tariff_heading": "82119200",
#             "customs_notification": "10.00 %",
#             "basic_customs_duty_rate": "43729.70",
#             "basic_customs_duty_notification": "011/2021 17",
#             "basic_customs_duty_amount": "0.00",
#             "unit": "KGS",
#             "assessed_value": "437297.28",
#             "central_excise_tariff_heading": "NOEXCISE",
#             "excise_duty_rate": "0.00 %",
#             "excise_duty_amount": "0.00",
#             "education_cess_on_cvd": "0.00 %",
#             "secondary_higher_education_cess_on_cvd": "0.00 %",
#             "customs_education_cess": "0.00 %",
#             "customs_secondary_higher_education_cess": "0.00 %",
#             "social_welfare_surcharge": "10.00 %",
#             "social_welfare_surcharge_amount": "4373.00",
#             "igst_details": {
#                 "igst_notification": "001/2017 III301A",
#                 "integrated_gst_rate": "18.00 %",
#                 "integrated_gst_amount": "87372.00"
#             },
#             "gst_cess_details": {
#                 "gst_cess_notification": "001/2017 56",
#                 "gst_cess_rate": "0.00 %",
#                 "gst_cess_amount": "0.00"
#             },
#             "page_total": "391486.80"
#         },
#         {
#             "serial_number": "7",
#             "ritc_code": "82119200",
#             "description": "SS21 8 PC ROTATING KNIFE SET TOTAL 1500 PCS USD 10.9 FOB PERPC MADE OF STAINLESS STEEL 54.5X35.5X41 CM HC 2352",
#             "quantity": "2592.50",
#             "unit_price": "6.306654",
#             "customs_tariff_heading": "82119200",
#             "customs_notification": "10.00 %",
#             "basic_customs_duty_rate": "140192.40",
#             "basic_customs_duty_notification": "011/2021 17",
#             "basic_customs_duty_amount": "0.00",
#             "unit": "KGS",
#             "assessed_value": "1401923.60",
#             "central_excise_tariff_heading": "NOEXCISE",
#             "excise_duty_rate": "0.00 %",
#             "excise_duty_amount": "0.00",
#             "education_cess_on_cvd": "0.00 %",
#             "secondary_higher_education_cess_on_cvd": "0.00 %",
#             "customs_education_cess": "0.00 %",
#             "customs_secondary_higher_education_cess": "0.00 %",
#             "social_welfare_surcharge": "10.00 %",
#             "social_welfare_surcharge_amount": "14019.20",
#             "igst_details": {
#                 "igst_notification": "001/2017 III301A",
#                 "integrated_gst_rate": "18.00 %",
#                 "integrated_gst_amount": "280104.31"
#             },
#             "gst_cess_details": {
#                 "gst_cess_notification": "001/2017 56",
#                 "gst_cess_rate": "0.00 %",
#                 "gst_cess_amount": "0.00"
#             },
#             "page_total": "825802.70"
#         }
#     ],
#     "invoice_gross_total": "825802.70",
#     "be_gross_total": "825802.70",
#     "duty_breakup": {
#         "bcd": "266559.90",
#         "ncd_duty": "0.00",
#         "antid": "0.00",
#         "safeguard_duty": "0.00",
#         "cvd": "0.00",
#         "cess": "0.00",
#         "gsia": "0.00",
#         "tta": "0.00",
#         "education_cess_on_cvd": "0.00",
#         "customs_education_cess": "0.00",
#         "additional_duty_imports": "0.00",
#         "secondary_higher_education_cess_on_cvd": "0.00",
#         "customs_secondary_higher_education_cess": "0.00"
#     },
#     "duty_payable": "825803",
#     "container_details": [
#         {
#             "igm_number": "2371888",
#             "container_number": "F SEGU1330114"
#         }
#     ],
#     "gstin_details": {
#         "ad_code": "0510010",
#         "gstin": "33AAACL2937J1ZL",
#         "supplier_name": "BERGNER HK LIMITED",
#         "document_details": [
#             {
#                 "document_type": "-",
#                 "state_code": "33",
#                 "state_name": "Tamil Nadu",
#                 "integrated_gst_assessed_value": "2958815",
#                 "integrated_gst_amount": "532587",
#                 "gst_cess_amount": "0"
#             }
#         ]
#     }
# }
# ```
#
# I have tried to convert all the data into JSON format without skipping any details. The structure maintains the relationship between different sections and data points. Let me know if you need any changes.
